# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
df_WS = pd.read_csv('/Users/lynnekiesling/Documents/projects/SLAC TESS/Ercot_LZ_SOUTH.csv',parse_dates=True,index_col=[0]) # For year 2016
df_WS.head()
print(df_WS.head())
df_WS = df_WS[~df_WS.index.duplicated(keep='last')]
# the ~ inverts the true/false, square bracket says "keep true"
#is this robust to more than one duplicate? yes
# Out:
#                         DA     RT
# 2016-01-01 00:00:00  18.22  15.48
# 2016-01-01 00:05:00  18.22  15.48
# 2016-01-01 00:10:00  18.22  15.48
# 2016-01-01 00:15:00  18.22  15.33
# 2016-01-01 00:20:00  18.22  15.33

# %%
plt.figure(figsize=(12,8))
plt.plot(df_WS.index, df_WS['DA'], label = "Day Ahead")
plt.plot(df_WS.index, df_WS['RT'], label = "Real Time")
plt.title("Day Ahead and Real Time Prices, 2016")
plt.legend()
plt.show()
# Out:
# /Users/lynnekiesling/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
start_Week1 = datetime.datetime(2016, 7, 1, 0, 0, 0)
end_Week1 = datetime.datetime(2016, 7, 7, 23, 59, 59)
df_JulyWeek1 = df_WS[(df_WS.index > start_Week1) & (df_WS.index < end_Week1) ]
df_JulyWeek1.head
# Out:
# <bound method NDFrame.head of                         DA     RT
# 2016-07-01 00:05:00  19.36  19.48
# 2016-07-01 00:10:00  19.36  19.48
# 2016-07-01 00:15:00  19.36  19.92
# 2016-07-01 00:20:00  19.36  19.92
# 2016-07-01 00:25:00  19.36  19.92
# ...                    ...    ...
# 2016-07-07 23:35:00  19.67  18.36
# 2016-07-07 23:40:00  19.67  18.36
# 2016-07-07 23:45:00  19.67  17.90
# 2016-07-07 23:50:00  19.67  17.90
# 2016-07-07 23:55:00  19.67  17.90
#
# [2015 rows x 2 columns]>

# %%
plt.clf()
plt.figure(figsize=(12,8))
plt.plot(df_JulyWeek1.index, df_JulyWeek1['DA'], label = "Day Ahead")
plt.plot(df_JulyWeek1.index, df_JulyWeek1['RT'], label = "Real Time")
plt.title("Day Ahead and Real Time Prices, July 1-7 2016")
plt.legend()
plt.show()

# %%
df_JulyWeek1.describe()
# Out:
#                 DA           RT
# count  2015.000000  2015.000000
# mean     29.446298    23.241404
# std      15.412832    10.690522
# min       9.490000     7.090000
# 25%      18.235000    17.735000
# 50%      24.790000    20.680000
# 75%      36.295000    27.080000
# max      93.860000   129.880000

# %%
df_JulyWeek1.corr()
# Out:
#           DA        RT
# DA  1.000000  0.551788
# RT  0.551788  1.000000
